# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn
plt.style.use('default')
# %matplotlib inline

# %%
df=pd.read_csv("Static/Provisional_COVID-19_Deaths_by_Sex_and_Age.csv")

# %%
df.head(5)
# Out:
#    Data As Of  Start Date    End Date     Group  Year  Month          State  \
# 0  06/02/2022  01/01/2020  05/28/2022  By Total   NaN    NaN  United States
# 1  06/02/2022  01/01/2020  05/28/2022  By Total   NaN    NaN  United States
# 2  06/02/2022  01/01/2020  05/28/2022  By Total   NaN    NaN  United States
# 3  06/02/2022  01/01/2020  05/28/2022  By Total   NaN    NaN  United States
# 4  06/02/2022  01/01/2020  05/28/2022  By Total   NaN    NaN  United States
#
#          Sex     Age Group  COVID-19 Deaths  Total Deaths  Pneumonia Deaths  \
# 0  All Sexes      All Ages        1005236.0     8144650.0          899878.0
# 1  All Sexes  Under 1 year            299.0       45962.0             587.0
# 2  All Sexes    0-17 years           1086.0       81532.0            1670.0
# 3  All Sexes     1-4 years            143.0        8617.0             342.0
# 4  All Sexes    5-14 years            341.0       13641.0             476.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90882 entries, 0 to 90881
# Data columns (total 16 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Data As Of                                90882 non-null  object
#  1   Start Date                                90882 non-null  object
#  2   End Date                                  90882 non-null  object
#  3   Group                                     90882 non-null  object
#  4   Year                                      88128 non-null  float64
#  5   Month                                     79866 non-null  float64
#  6   State                                     90882 non-null  object
#  7   Sex                                       90882 non-null  object
#  8   Age Group                                 90882 non-null  object
#  9   COVID-19 Deaths                           67368 non-null  float64
# ...

# %%
df['End Date']=pd.to_datetime(df['End Date'])

# %%
df['Start Date']=pd.to_datetime(df['Start Date'])

# %%
df['Data As Of']=pd.to_datetime(df['Data As Of'])

# %%
for col in df.select_dtypes(include=['datetime64']).columns.tolist():
    df.style.format({"df[col]":
                    lambda t:t.strftime("%Y-%m-%d")})

# %%
df.tail(5)
# Out:
#       Data As Of Start Date   End Date     Group    Year  Month        State  \
# 90877 2022-06-02 2022-05-01 2022-05-28  By Month  2022.0    5.0  Puerto Rico
# 90878 2022-06-02 2022-05-01 2022-05-28  By Month  2022.0    5.0  Puerto Rico
# 90879 2022-06-02 2022-05-01 2022-05-28  By Month  2022.0    5.0  Puerto Rico
# 90880 2022-06-02 2022-05-01 2022-05-28  By Month  2022.0    5.0  Puerto Rico
# 90881 2022-06-02 2022-05-01 2022-05-28  By Month  2022.0    5.0  Puerto Rico
#
#           Sex          Age Group  COVID-19 Deaths  Total Deaths  \
# 90877  Female        50-64 years              NaN          68.0
# 90878  Female        55-64 years              NaN          56.0
# 90879  Female        65-74 years              NaN         108.0
# 90880  Female        75-84 years             16.0         222.0
# 90881  Female  85 years and over             28.0         279.0
#
#        Pneumonia Deaths  Pneumonia and COVID-19 Deaths  Influenza Deaths  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90882 entries, 0 to 90881
# Data columns (total 16 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Data As Of                                90882 non-null  datetime64[ns]
#  1   Start Date                                90882 non-null  datetime64[ns]
#  2   End Date                                  90882 non-null  datetime64[ns]
#  3   Group                                     90882 non-null  object
#  4   Year                                      88128 non-null  float64
#  5   Month                                     79866 non-null  float64
#  6   State                                     90882 non-null  object
#  7   Sex                                       90882 non-null  object
#  8   Age Group                                 90882 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# Data As Of                                      0
# Start Date                                      0
# End Date                                        0
# Group                                           0
# Year                                         2754
# Month                                       11016
# State                                           0
# Sex                                             0
# Age Group                                       0
# COVID-19 Deaths                             23514
# Total Deaths                                12755
# Pneumonia Deaths                            27554
# Pneumonia and COVID-19 Deaths               23090
# Influenza Deaths                            16242
# Pneumonia, Influenza, or COVID-19 Deaths    26742
# Footnote                                    30089
# dtype: int64

# %%
df['Year']=df['Year'].fillna(2020)

# %%
df.columns
# Out:
# Index(['Data As Of', 'Start Date', 'End Date', 'Group', 'Year', 'Month',
#        'State', 'Sex', 'Age Group', 'COVID-19 Deaths', 'Total Deaths',
#        'Pneumonia Deaths', 'Pneumonia and COVID-19 Deaths', 'Influenza Deaths',
#        'Pneumonia, Influenza, or COVID-19 Deaths', 'Footnote'],
#       dtype='object')

# %%
df. drop(["Month","Footnote"], axis=1, inplace=True)

# %%
df.isnull().sum()
# Out:
# Data As Of                                      0
# Start Date                                      0
# End Date                                        0
# Group                                           0
# Year                                            0
# State                                           0
# Sex                                             0
# Age Group                                       0
# COVID-19 Deaths                             23514
# Total Deaths                                12755
# Pneumonia Deaths                            27554
# Pneumonia and COVID-19 Deaths               23090
# Influenza Deaths                            16242
# Pneumonia, Influenza, or COVID-19 Deaths    26742
# dtype: int64

# %%
# df=df.fillna(0)
df=df.dropna()

# %%
nRow, nCol = df.shape

# %%
nRow,nCol
# Out:
# (30089, 14)

# %%
df.isnull().sum()
# Out:
# Data As Of                                  0
# Start Date                                  0
# End Date                                    0
# Group                                       0
# Year                                        0
# State                                       0
# Sex                                         0
# Age Group                                   0
# COVID-19 Deaths                             0
# Total Deaths                                0
# Pneumonia Deaths                            0
# Pneumonia and COVID-19 Deaths               0
# Influenza Deaths                            0
# Pneumonia, Influenza, or COVID-19 Deaths    0
# dtype: int64

# %%
df.index=df['End Date']

# %%
# Calculating moving average of Covid 19 Deaths
# For these case i would use Cumulative Moving Average
df1=df['COVID-19 Deaths'].to_frame()
df1.head()
# Out:
#             COVID-19 Deaths
# End Date
# 2022-05-28        1005236.0
# 2022-05-28            299.0
# 2022-05-28           1086.0
# 2022-05-28            143.0
# 2022-05-28            341.0

# %%
df1["SMA30"]=df1['COVID-19 Deaths'].rolling(30).mean()

# %%
df['Age Group'].unique()
# Out:
# array(['All Ages', 'Under 1 year', '0-17 years', '1-4 years',
#        '5-14 years', '15-24 years', '18-29 years', '25-34 years',
#        '30-39 years', '35-44 years', '40-49 years', '45-54 years',
#        '50-64 years', '55-64 years', '65-74 years', '75-84 years',
#        '85 years and over'], dtype=object)

# %%
df['Sex'].unique()
# Out:
# array(['All Sexes', 'Male', 'Female'], dtype=object)

# %%
df1.dropna(inplace=False)
# Out:
#             COVID-19 Deaths          SMA30
# End Date
# 2022-05-28         117251.0  101784.166667
# 2022-05-28          91112.0   71313.366667
# 2022-05-28         137373.0   75882.500000
# 2022-05-28         145668.0   80701.900000
# 2022-05-28         113285.0   84473.300000
# ...                     ...            ...
# 2022-05-28              0.0       9.800000
# 2022-05-28             50.0       9.933333
# 2022-05-28              0.0       9.933333
# 2022-05-28              0.0       8.433333
# 2022-05-28             28.0       7.466667
#
# [30060 rows x 2 columns]

# %%
df1.head(10)
# Out:
#             COVID-19 Deaths  SMA30
# End Date
# 2022-05-28        1005236.0    NaN
# 2022-05-28            299.0    NaN
# 2022-05-28           1086.0    NaN
# 2022-05-28            143.0    NaN
# 2022-05-28            341.0    NaN
# 2022-05-28           2674.0    NaN
# 2022-05-28           6334.0    NaN
# 2022-05-28          11275.0    NaN
# 2022-05-28          18280.0    NaN
# 2022-05-28          27870.0    NaN

# %%
df1[['COVID-19 Deaths','SMA30']].plot(label='SMA30',figsize=(16,8))
# Out:
# <AxesSubplot:xlabel='End Date'>

# %%
df["CMA30"]=df['COVID-19 Deaths'].expanding().mean()

# %%
df[df.index.duplicated()]
# Out:
#            Data As Of Start Date   End Date     Group    Year          State  \
# End Date
# 2022-05-28 2022-06-02 2020-01-01 2022-05-28  By Total  2020.0  United States
# 2022-05-28 2022-06-02 2020-01-01 2022-05-28  By Total  2020.0  United States
# 2022-05-28 2022-06-02 2020-01-01 2022-05-28  By Total  2020.0  United States
# 2022-05-28 2022-06-02 2020-01-01 2022-05-28  By Total  2020.0  United States
# 2022-05-28 2022-06-02 2020-01-01 2022-05-28  By Total  2020.0  United States
# ...               ...        ...        ...       ...     ...            ...
# 2022-05-28 2022-06-02 2022-05-01 2022-05-28  By Month  2022.0    Puerto Rico
# 2022-05-28 2022-06-02 2022-05-01 2022-05-28  By Month  2022.0    Puerto Rico
# 2022-05-28 2022-06-02 2022-05-01 2022-05-28  By Month  2022.0    Puerto Rico
# 2022-05-28 2022-06-02 2022-05-01 2022-05-28  By Month  2022.0    Puerto Rico
# 2022-05-28 2022-06-02 2022-05-01 2022-05-28  By Month  2022.0    Puerto Rico
#
# ...

# %%
# df2 = df[~df.index.duplicated(keep='first')]

# %%
df1["CMA30"]=df["CMA30"]

# %%
df1[['COVID-19 Deaths','CMA30']].plot(label='CMA',figsize=(18,8))
# Out:
# <AxesSubplot:xlabel='End Date'>

# %%
df['Sex'].unique()
# Out:
# array(['All Sexes', 'Male', 'Female'], dtype=object)

# %%
df.columns
# Out:
# Index(['Data As Of', 'Start Date', 'End Date', 'Group', 'Year', 'State', 'Sex',
#        'Age Group', 'COVID-19 Deaths', 'Total Deaths', 'Pneumonia Deaths',
#        'Pneumonia and COVID-19 Deaths', 'Influenza Deaths',
#        'Pneumonia, Influenza, or COVID-19 Deaths', 'CMA30'],
#       dtype='object')

# %%
# df.drop(df.loc[df['Sex'] == 'All Sexes'].index, inplace=True)

# %%
df['Age Group'].unique()
# Out:
# array(['All Ages', 'Under 1 year', '0-17 years', '1-4 years',
#        '5-14 years', '15-24 years', '18-29 years', '25-34 years',
#        '30-39 years', '35-44 years', '40-49 years', '45-54 years',
#        '50-64 years', '55-64 years', '65-74 years', '75-84 years',
#        '85 years and over'], dtype=object)

# %%
df.tail(20)
# Out:
#            Data As Of Start Date   End Date     Group    Year        State  \
# End Date
# 2022-03-31 2022-06-02 2022-03-01 2022-03-31  By Month  2022.0  Puerto Rico
# 2022-03-31 2022-06-02 2022-03-01 2022-03-31  By Month  2022.0  Puerto Rico
# 2022-03-31 2022-06-02 2022-03-01 2022-03-31  By Month  2022.0  Puerto Rico
# 2022-03-31 2022-06-02 2022-03-01 2022-03-31  By Month  2022.0  Puerto Rico
# 2022-03-31 2022-06-02 2022-03-01 2022-03-31  By Month  2022.0  Puerto Rico
# 2022-03-31 2022-06-02 2022-03-01 2022-03-31  By Month  2022.0  Puerto Rico
# 2022-04-30 2022-06-02 2022-04-01 2022-04-30  By Month  2022.0  Puerto Rico
# 2022-04-30 2022-06-02 2022-04-01 2022-04-30  By Month  2022.0  Puerto Rico
# 2022-04-30 2022-06-02 2022-04-01 2022-04-30  By Month  2022.0  Puerto Rico
# 2022-04-30 2022-06-02 2022-04-01 2022-04-30  By Month  2022.0  Puerto Rico
# 2022-04-30 2022-06-02 2022-04-01 2022-04-30  By Month  2022.0  Puerto Rico
# ...
